# %%
import pandas as pd
import numpy as np

# %%
number = pd.read_csv("number.csv", encoding ="utf-8", thousands = ',')
number.head()
# Out:
#     구분        계     1인가구    2인가구    3인가구    4인가구   5인 가구   6인가구  7인이상 가구
# 0   합계  3784705  1138860  931262  816946  686469  163555  37153    10460
# 1  종로구    60786    22835   14974   11060    8712    2397    618      190
# 2   중구    51503    19671   13086    9453    6844    1836    480      133
# 3  용산구    90164    31641   23505   17580   13121    3327    780      210
# 4  성동구   116401    37074   28668   24655   19874    4636   1164      330

# %%
number["1인가구율"] = (number["1인가구"] / number["계"]) * 100
number.head()
# Out:
#     구분        계     1인가구    2인가구    3인가구    4인가구   5인 가구   6인가구  7인이상 가구  \
# 0   합계  3784705  1138860  931262  816946  686469  163555  37153    10460
# 1  종로구    60786    22835   14974   11060    8712    2397    618      190
# 2   중구    51503    19671   13086    9453    6844    1836    480      133
# 3  용산구    90164    31641   23505   17580   13121    3327    780      210
# 4  성동구   116401    37074   28668   24655   19874    4636   1164      330
#
#        1인가구율
# 0  30.091117
# 1  37.566216
# 2  38.193892
# 3  35.092720
# 4  31.850242

# %%
health = pd.read_csv("health.csv", encoding = "utf-8", thousands = ',')
health.head()
# Out:
#     지역  현재흡연율  현재흡연자의 금연시도율  고위험음주율  스트레스 인지율
# 0  종로구   20.4          35.2    20.1      25.4
# 1   중구   22.2          26.9    20.3      28.6
# 2  용산구   19.5          31.9    18.9      28.7
# 3  성동구   20.5          39.3    16.2      28.4
# 4  광진구   19.4          30.9    17.0      30.4

# %%
# 전처리 - 평균화 수행
min_max_scaler = preprocessing.MinMaxScaler() # 

x_scaled = min_max_scaler.fit_transform(x.astype(float)) # 데이터만 있는 x값들을 전처리 수행함.
number_norm = pd.DataFrame(x_scaled, columns = col, index = number.index) # crime_norm이라는 데이터 프레임을 새로 만듬.
number_norm.head()

# col2 데이터 속성 정리
col2=['현재흡연율','현재흡연자의 금연시도율','고위험음주율','스트레스 인지율']
# crime[col2] 부분을 그대로 crime_norm[col2]에 이식함.
number_norm[col2] = number[col2]
number_norm.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-39383b744d01> in <module>()
#       2 #min_max_scaler = preprocessing.MinMaxScaler() #
#       3
# ----> 4 x_scaled = min_max_scaler.fit_transform(x.astype(float)) # 데이터만 있는 x값들을 전처리 수행함.
#       5 number_norm = pd.DataFrame(x_scaled, columns = col, index = number.index) # crime_norm이라는 데이터 프레임을 새로 만듬.
#       6 number_norm.head()
#
# NameError: name 'min_max_scaler' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
sns.pairplot(health, vars=["현재흡연율","현재흡연자의 금연시도율","고위험음주율","스트레스 인지율"],
             kind='reg',size = 2)
plt.show()

# %%
sns.set_style("darkgrid")
sns.lmplot(x="1인가구율", y="현재흡연율", data=[number,health], size=4)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-a5db4d884101> in <module>()
#       1 sns.set_style("darkgrid")
# ----> 2 sns.lmplot(x="1인가구율", y="현재흡연율", data=[number,health], size=4)
#       3 plt.show()
#
# C:\Miniconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     550     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     551     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 552     data = data[cols]
#     553
#     554     # Initialize the grid
#
# ...

# %%
sns.pairplot(health, x_vars = ['1인가구율'], 
             y_vars = ['현재흡연율', '현재흡연자의 금연시도율','고위험음주율','스트레스 인지율'],
            kind = 'reg',
            size = 2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1인가구율'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-23c8b92f6bc9> in <module>()
# ...
